# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from sklearn.model_selection import train_test_split
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
import random
from utils.utils import *

# %% [markdown]
# ## Loading the data

# %%
data_indexes = [(i+1,j+1) for i in range(5) for j in range(2000)]

# %%
identify_nan = False
idx_discard = set()

if identify_nan:
    #Identify data with NaN to discard them
    for idx in data_indexes:
        mat = np.loadtxt(f'./datos_tfg/datos_tfg/tfg_datos_{idx[0]}_{idx[1]}.txt')
        if np.isnan(mat[-1]).any():
            idx_discard.add(idx)
    #Save de indexes
    with open('idx_nan.txt', 'w') as f:
        for idx in idx_discard:
            f.write(f"{idx[0]}, {idx[1]}\n")


with open('./utils/idx_nan.txt', 'r') as f:
    for line in f:
        idx = line.strip().split(',')
        idx_discard.add((int(idx[0]), int(idx[1].strip())))

# %%
parameters = load_parameter_list()

# %%
df_parameters = pd.DataFrame(parameters, columns=['cx', 'cy', 'a', 'b', 'theta', 'e1', 'e2'])
df_parameters['data_index'] = data_indexes
df_parameters = df_parameters[~df_parameters['data_index'].isin(idx_discard)]
df_parameters.reset_index(inplace = True, drop = True)

# %% [markdown]
# ## Parameters analysis

# %%
print(f'There are {len(df_parameters)} combination of parameters.')
# Out:
# There are 7067 combination of parameters.

# %%
df_parameters.drop(['data_index'], axis=1).describe().transpose().drop(['25%','75%'], axis=1)
# Out:
#         count      mean       std       min       50%        max
# cx     7067.0  0.475365  1.008015 -3.102034  0.471488   4.378377
# cy     7067.0  3.524298  0.975501  0.572812  3.496492   6.764944
# a      7067.0  1.339595  0.562254  0.015081  1.313752   4.032865
# b      7067.0  0.546197  0.388177  0.000054  0.479559   2.397364
# theta  7067.0  0.199955  0.316850 -0.876184  0.202016   1.435599
# e1     7067.0  2.616918  1.587688  0.000006  2.472297  11.031250
# e2     7067.0  4.075273  2.242720  0.000887  4.067062  12.517647

# %%
fig, axes = plt.subplots(2, 4, figsize=(12, 8))

axes = axes.flatten()

for i, col in enumerate(df_parameters.columns[:-1]):
    sns.histplot(df_parameters[col], ax=axes[i])
    #axes[i].set_title(col)

axes[-1].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing training data

# %%
n = 9
idx_viz = []
for i in range(n):
    idx_1 = random.randint(1,5)
    idx_2 = random.randint(1,2000)
    while (idx_1, idx_2) in idx_discard:
        idx_1 = random.randint(1,5)
        idx_2 = random.randint(1,2000)
    idx_viz.append((idx_1,idx_2))

visualize(idx_viz, parameters, cols = 3)

# %% [markdown]
# ## Preprocessing

# %%
X = pd.DataFrame(df_parameters['data_index'])
y = df_parameters.drop(['data_index'], axis=1)

# %%
mskf = MultilabelStratifiedKFold(n_splits=5, shuffle = True, random_state=0)
X.loc[:, 'fold'] = -1
y.loc[:, 'fold'] = -1

# %%
for fold_ , (train_, valid_) in enumerate(mskf.split(X=X, y=y)):
    X.loc[valid_, 'fold'] = fold_
    y.loc[valid_, 'fold'] = fold_

# %%
show_distribution = True

for i in range(5):
    print(f'------------- FOLD {i} -------------')
    params = y[y['fold'] == i]
    print(params.describe().drop(['25%','75%']).transpose())
    if show_distribution:
        fig, axes = plt.subplots(2, 4, figsize=(12, 5))

        axes = axes.flatten()

        for i, col in enumerate(params.columns[:-1]):
            sns.histplot(params[col], ax=axes[i])
            #axes[i].set_title(col)

        axes[-1].axis('off')
        plt.tight_layout()
        plt.show()
# Out:
# ------------- FOLD 0 -------------
#         count      mean       std       min       50%        max
# cx     1413.0  0.503943  1.014470 -3.102034  0.482142   3.982865
# cy     1413.0  3.518464  0.939864  0.829259  3.484508   6.550426
# a      1413.0  1.348714  0.572697  0.086826  1.323007   4.032865
# b      1413.0  0.547969  0.384199  0.002255  0.481740   2.397364
# theta  1413.0  0.205693  0.317228 -0.828643  0.205999   1.435599
# e1     1413.0  2.628611  1.576898  0.000006  2.453806  10.031247
# e2     1413.0  3.961923  2.194605  0.002443  3.986772   9.674336
# fold   1413.0  0.000000  0.000000  0.000000  0.000000   0.000000
# ------------- FOLD 1 -------------
#         count      mean       std       min       50%        max
# cx     1414.0  0.510198  1.023337 -2.835535  0.504378   4.138670
# cy     1414.0  3.518049  0.985945  0.572812  3.487631   6.358418
# a      1414.0  1.331586  0.543732  0.015081  1.308447   3.390795
# b      1414.0  0.537892  0.383824  0.000287  0.475390   2.125607
# theta  1414.0  0.193996  0.317662 -0.876184  0.188082   1.128053
# e1     1414.0  2.577364  1.572110  0.003543  2.396684   9.365492
# e2     1414.0  4.066877  2.250417  0.016106  4.011047  11.566109
# fold   1414.0  1.000000  0.000000  1.000000  1.000000   1.000000
# ------------- FOLD 2 -------------
#         count      mean       std       min       50%        max
# cx     1413.0  0.447437  0.952555 -2.542831  0.472337   3.498380
# cy     1413.0  3.522198  0.979395  0.883374  3.473390   6.764944
# a      1413.0  1.330617  0.559536  0.042182  1.300410   3.851698
# b      1413.0  0.552906  0.381652  0.000674  0.489494   2.154628
# theta  1413.0  0.204182  0.307361 -0.756269  0.201116   1.297448
# e1     1413.0  2.672125  1.599697  0.004380  2.527688   9.703464
# e2     1413.0  4.126414  2.238281  0.001369  4.190051  12.517647
# fold   1413.0  2.000000  0.000000  2.000000  2.000000   2.000000
# ------------- FOLD 3 -------------
#         count      mean       std       min       50%        max
# cx     1413.0  0.464506  1.007847 -2.808958  0.458550   4.378377
# cy     1413.0  3.565142  0.995047  0.650975  3.547921   6.572892
# a      1413.0  1.348095  0.570667  0.032099  1.316488   3.702683
# b      1413.0  0.549113  0.398461  0.000054  0.473784   2.219840
# theta  1413.0  0.197804  0.322080 -0.737332  0.200545   1.373240
# e1     1413.0  2.636827  1.570963  0.013126  2.517926  11.031250
# e2     1413.0  4.109426  2.241280  0.007117  4.023651  10.745827
# fold   1413.0  3.000000  0.000000  3.000000  3.000000   3.000000
# ------------- FOLD 4 -------------
#         count      mean       std       min       50%        max
# cx     1414.0  0.450732  1.039355 -2.830086  0.451605   3.368566
# cy     1414.0  3.497660  0.976460  0.760713  3.497157   6.681080
# a      1414.0  1.338972  0.564703  0.102572  1.309869   3.642976
# b      1414.0  0.543111  0.392860  0.000130  0.467462   2.113519
# theta  1414.0  0.198103  0.320012 -0.835219  0.211374   1.244875
# e1     1414.0  2.569725  1.618147  0.000099  2.413303   8.355786
# e2     1414.0  4.111705  2.287161  0.000887  4.130219  12.385929
# fold   1414.0  4.000000  0.000000  4.000000  4.000000   4.000000

# %%
X_train = X[(X['fold'] == 0) | (X['fold'] == 1) | (X['fold'] == 2)]
y_train = y[(y['fold'] == 0) | (y['fold'] == 1) | (y['fold'] == 2)]

X_validation = X[X['fold'] == 3]
y_validation = y[y['fold'] == 3]

X_test = X[X['fold'] == 4]
y_test = y[y['fold'] == 4]

# %%
y_train.describe().transpose()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# cx     4240.0  0.487198  0.997455 -3.102034 -0.189634  0.482379  1.156605
# cy     4240.0  3.519570  0.968392  0.572812  2.843014  3.481134  4.202105
# a      4240.0  1.336971  0.558707  0.015081  0.923032  1.314412  1.702143
# b      4240.0  0.546254  0.383188  0.000287  0.234826  0.482485  0.794890
# theta  4240.0  0.201289  0.314089 -0.876184 -0.006421  0.199228  0.416379
# e1     4240.0  2.626022  1.583046  0.000006  1.394054  2.471254  3.702048
# e2     4240.0  4.051741  2.228414  0.001369  2.244777  4.065019  5.849289
# fold   4240.0  1.000000  0.816497  0.000000  0.000000  1.000000  2.000000
#
#              max
# cx      4.138670
# cy      6.764944
# a       4.032865
# b       2.397364
# theta   1.435599
# e1     10.031247
# e2     12.517647
# fold    2.000000

# %%
y_validation.describe().transpose()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# cx     1413.0  0.464506  1.007847 -2.808958 -0.214324  0.458550  1.109117
# cy     1413.0  3.565142  0.995047  0.650975  2.895266  3.547921  4.254960
# a      1413.0  1.348095  0.570667  0.032099  0.933188  1.316488  1.725661
# b      1413.0  0.549113  0.398461  0.000054  0.221013  0.473784  0.802873
# theta  1413.0  0.197804  0.322080 -0.737332 -0.013443  0.200545  0.404785
# e1     1413.0  2.636827  1.570963  0.013126  1.409820  2.517926  3.663847
# e2     1413.0  4.109426  2.241280  0.007117  2.263858  4.023651  5.987022
# fold   1413.0  3.000000  0.000000  3.000000  3.000000  3.000000  3.000000
#
#              max
# cx      4.378377
# cy      6.572892
# a       3.702683
# b       2.219840
# theta   1.373240
# e1     11.031250
# e2     10.745827
# fold    3.000000

# %%
y_test.describe().transpose()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# cx     1414.0  0.450732  1.039355 -2.830086 -0.228739  0.451605  1.165235
# cy     1414.0  3.497660  0.976460  0.760713  2.819180  3.497157  4.189301
# a      1414.0  1.338972  0.564703  0.102572  0.926709  1.309869  1.712440
# b      1414.0  0.543111  0.392860  0.000130  0.226787  0.467462  0.782905
# theta  1414.0  0.198103  0.320012 -0.835219 -0.007838  0.211374  0.420533
# e1     1414.0  2.569725  1.618147  0.000099  1.263967  2.413303  3.603638
# e2     1414.0  4.111705  2.287161  0.000887  2.192965  4.130219  5.997236
# fold   1414.0  4.000000  0.000000  4.000000  4.000000  4.000000  4.000000
#
#              max
# cx      3.368566
# cy      6.681080
# a       3.642976
# b       2.113519
# theta   1.244875
# e1      8.355786
# e2     12.385929
# fold    4.000000

# %%
save_indexes(X_train['data_index'], './utils/train.txt')
save_indexes(X_validation['data_index'], './utils/validation.txt')
save_indexes(X_test['data_index'], './utils/test.txt')
